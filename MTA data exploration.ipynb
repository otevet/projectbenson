# %%
#import dependencies
import numpy as np
import pandas as pd
import time
import json
import matplotlib
from pprint import pprint

# %%
#load the raw data file retrieved from MTA website
#convert to pandas dataframe

df = pd.read_csv('turnstile_170624.txt')
new_header = []
for col in df.columns:
    col=col.strip()
    new_header.append(col)
df.columns = new_header
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
df.head(20)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/17/2017  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/17/2017  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/17/2017  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/17/2017  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/17/2017  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/17/2017  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2017  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2017  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2017  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2017  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2017  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2017  20:00:00
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/17/2017
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/17/2017
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/17/2017
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/17/2017
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/17/2017
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/17/2017
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/18/2017
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/18/2017
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/18/2017
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  06/18/2017
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/18/2017
# ...

# %%
#Division is not neccesary for this analysis 
#archaic info pre 1940's
df.drop(df.columns[[5]], axis=1, inplace=True)
df.head(20)
# Out:
#      C/A  UNIT       SCP STATION LINENAME        DATE      TIME     DESC  \
# 0   A002  R051  02-00-00   59 ST  NQR456W  06/17/2017  00:00:00  REGULAR
# 1   A002  R051  02-00-00   59 ST  NQR456W  06/17/2017  04:00:00  REGULAR
# 2   A002  R051  02-00-00   59 ST  NQR456W  06/17/2017  08:00:00  REGULAR
# 3   A002  R051  02-00-00   59 ST  NQR456W  06/17/2017  12:00:00  REGULAR
# 4   A002  R051  02-00-00   59 ST  NQR456W  06/17/2017  16:00:00  REGULAR
# 5   A002  R051  02-00-00   59 ST  NQR456W  06/17/2017  20:00:00  REGULAR
# 6   A002  R051  02-00-00   59 ST  NQR456W  06/18/2017  00:00:00  REGULAR
# 7   A002  R051  02-00-00   59 ST  NQR456W  06/18/2017  04:00:00  REGULAR
# 8   A002  R051  02-00-00   59 ST  NQR456W  06/18/2017  08:00:00  REGULAR
# 9   A002  R051  02-00-00   59 ST  NQR456W  06/18/2017  12:00:00  REGULAR
# 10  A002  R051  02-00-00   59 ST  NQR456W  06/18/2017  16:00:00  REGULAR
# 11  A002  R051  02-00-00   59 ST  NQR456W  06/18/2017  20:00:00  REGULAR
# ...

# %%
#Convert columsn date and time to a single timedate column
df['DATETIME'] = pd.to_datetime(df['DATE'] + ' ' + df['TIME'], format = '%m/%d/%Y %H:%M:%S')
df.head(20)
df.drop('DATE', axis=1, inplace=True)

# %%
df.drop('TIME', axis=1, inplace=True)
df.head(20)
# Out:
#      C/A  UNIT       SCP STATION LINENAME     DESC  ENTRIES    EXITS  \
# 0   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6224816  2107317
# 1   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6224850  2107322
# 2   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6224885  2107352
# 3   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225005  2107452
# 4   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225248  2107513
# 5   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225548  2107565
# 6   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225716  2107586
# 7   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225741  2107590
# 8   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225762  2107607
# 9   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225879  2107676
# 10  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226063  2107714
# 11  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226295  2107755
# 12  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226407  2107778
# ...

# %%
df.drop('EXITS', axis=1, inplace=True)

# %%
df.head(50)
# Out:
#      C/A  UNIT       SCP STATION LINENAME     DESC  ENTRIES  \
# 0   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6224816
# 1   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6224850
# 2   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6224885
# 3   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225005
# 4   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225248
# 5   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225548
# 6   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225716
# 7   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225741
# 8   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225762
# 9   A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6225879
# 10  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226063
# 11  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226295
# 12  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226407
# 13  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226413
# 14  A002  R051  02-00-00   59 ST  NQR456W  REGULAR  6226460
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           C/A  UNIT       SCP        STATION LINENAME     DESC  ENTRIES  \
# 0        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6224816
# 1        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6224850
# 2        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6224885
# 3        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6225005
# 4        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6225248
# 5        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6225548
# 6        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6225716
# 7        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6225741
# 8        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6225762
# 9        A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6225879
# 10       A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6226063
# 11       A002  R051  02-00-00          59 ST  NQR456W  REGULAR  6226295
# ...

# %%
df['ENTRIES'].describe()
# Out:
# count    1.974160e+05
# mean     3.887172e+07
# std      2.067859e+08
# min      0.000000e+00
# 25%      4.880605e+05
# 50%      2.652587e+06
# 75%      6.788725e+06
# max      2.130434e+09
# Name: ENTRIES, dtype: float64
